# %%
for i in range(1, 255):
    ch = chr(i)
    
    print ('{} belongs to = {}'.format(i,ch))
# Out:
# 1 belongs to =
# 2 belongs to =
# 3 belongs to =
# 4 belongs to =
# 5 belongs to =
# 6 belongs to =
# 7 belongs to =
# 8 belongs to =
# 9 belongs to =
# 10 belongs to =
#
# 11 belongs to =
# 12 belongs to =
# 13 belongs to =
# 14 belongs to =
# 15 belongs to =
# 16 belongs to =
# 17 belongs to =
# 18 belongs to =
# 19 belongs to =
# 20 belongs to =
# 21 belongs to =
# 22 belongs to =
# 23 belongs to =
# 24 belongs to =
# 25 belongs to =
# 26 belongs to =
# 27 belongs to =
# 28 belongs to =
# 29 belongs to =
# 30 belongs to =
# 31 belongs to =
# 32 belongs to =
# 33 belongs to = !
# 34 belongs to = "
# 35 belongs to = #
# 36 belongs to = $
# 37 belongs to = %
# 38 belongs to = &
# 39 belongs to = '
# 40 belongs to = (
# 41 belongs to = )
# 42 belongs to = *
# 43 belongs to = +
# 44 belongs to = ,
# 45 belongs to = -
# 46 belongs to = .
# 47 belongs to = /
# 48 belongs to = 0
# 49 belongs to = 1
# 50 belongs to = 2
# 51 belongs to = 3
# 52 belongs to = 4
# 53 belongs to = 5
# ...
